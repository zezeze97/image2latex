# %%
from im2latex.im2latex_infer import Recognition_Inference
from mmcv.image import imread
from IPython.display import Image as displayImage
from IPython.display import Latex

config_file = '../configs/textrecog/master/master_Resnet31_withGCB_im2latex.py'
checkpoint_file = '../expr_result/im2latex_res31/pretrained.pth'

img_path = '/home/zhangzr/Master-im2latex/data/im2latex_data/test_img/1a2f101131.png'

im2latex_model = Recognition_Inference(config_file, checkpoint_file, samples_per_gpu=64)
result = im2latex_model.predict_batch([imread(img_path)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128097/1069015152.py in <module>
#       9 img_path = '/home/zhangzr/Master-im2latex/data/im2latex_data/test_img/1a2f101131.png'
#      10
# ---> 11 im2latex_model = Recognition_Inference(config_file, checkpoint_file, samples_per_gpu=64)
#      12 result = im2latex_model.predict_batch([imread(img_path)])
#
# ~/Master-im2latex/im2latex/im2latex_infer.py in __init__(self, config_file, checkpoint_file, samples_per_gpu)
#      46         self.config_file = config_file
#      47         self.checkpoint_file = checkpoint_file
# ---> 48         super().__init__(config_file, checkpoint_file)
#      49         self.samples_per_gpu = samples_per_gpu
#      50
#
# ~/Master-im2latex/im2latex/im2latex_infer.py in __init__(self, config_file, checkpoint_file, device)
#      23         self.config_file = config_file
#      24         self.checkpoint_file = checkpoint_file
# ---> 25         self.model = build_model(config_file, checkpoint_file)
#      26
#      27         if device is None:
#
# ~/Master-im2latex/im2latex/im2latex_infer.py in build_model(config_file, checkpoint_file)
#      10 def build_model(config_file, checkpoint_file):
#      11     device = 'cpu'
# ---> 12     model = init_detector(config_file, checkpoint=checkpoint_file, device=device)
#      13
#      14     if model.cfg.data.test['type'] == 'ConcatDataset':
#
# ~/Master-im2latex/mmdetection-2.11.0/mmdet/apis/inference.py in init_detector(config, checkpoint, device, cfg_options)
#      29     """
#      30     if isinstance(config, str):
# ---> 31         config = mmcv.Config.fromfile(config)
#      32     elif not isinstance(config, mmcv.Config):
#      33         raise TypeError('config must be a filename or Config object, '
#
# ~/anaconda3/envs/im2latex/lib/python3.7/site-packages/mmcv/utils/config.py in fromfile(filename, use_predefined_variables, import_custom_modules)
#     330                  import_custom_modules=True):
#     331         cfg_dict, cfg_text = Config._file2dict(filename,
# --> 332                                                use_predefined_variables)
#     333         if import_custom_modules and cfg_dict.get('custom_imports', None):
#     334             import_modules_from_strings(**cfg_dict['custom_imports'])
#
# ~/anaconda3/envs/im2latex/lib/python3.7/site-packages/mmcv/utils/config.py in _file2dict(filename, use_predefined_variables)
#     204                 sys.path.insert(0, temp_config_dir)
#     205                 Config._validate_py_syntax(filename)
# --> 206                 mod = import_module(temp_module_name)
#     207                 sys.path.pop(0)
#     208                 cfg_dict = {
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/anaconda3/envs/im2latex/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /tmp/tmpds7ai72s/tmpd8awcf1u.py in <module>
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/zhangzr/Master_image2latex/data/im2latex_data/master_data/keys.txt'

# %%
latex_pred = ''
for token in result[0]['text']:
    latex_pred += token + ' '
latex_pred = '$$'+latex_pred+'$$'
print('lenth: ',len(latex_pred.split(' ')))
print(latex_pred)
displayImage(img_path)
# Out:
# lenth:  76
# $$\mathrm { q u e r y } = Z ^ { l - 1 } { \bf w } _ { Q } \mathrm { , ~ k e y } = Z ^ { l - 1 } { \bf w } _ { K } , \mathrm { ~ v a l u e } = Z ^ { l - 1 } { \bf w } _ { V } , $$

# %%
Latex(latex_pred.replace('\f','\\f'))
# Out:
# $$\mathrm { q u e r y } = Z ^ { l - 1 } { \bf w } _ { Q } \mathrm { , ~ k e y } = Z ^ { l - 1 } { \bf w } _ { K } , \mathrm { ~ v a l u e } = Z ^ { l - 1 } { \bf w } _ { V } , $$
